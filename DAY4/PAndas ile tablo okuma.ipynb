# %% [markdown]
# # HTML den okuma

# %%
import pandas as pd

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 330.3 kB/s eta 0:00:12
#    ---------------------------------------- 0.0/3.8 MB 326.8 kB/s eta 0:00:12
#     --------------------------------------- 0.1/3.8 MB 435.7 kB/s eta 0:00:09
#    - -------------------------------------- 0.2/3.8 MB 762.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.3/3.8 MB 1.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.8 MB 1.7 MB/s eta 0:00:02
#    -------- ------------------------------- 0.8/3.8 MB 2.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.8 MB 2.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.5/3.8 MB 3.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.9/3.8 MB 4.0 MB/s eta 0:00:01
# ...

# %%
df=pd.read_html("https://tr.wikipedia.org/wiki/D%C3%BCnyan%C4%B1n_en_zenginleri_listesi")[2]
df
# Out:
#    Sıra                      İsim       Servet  Yaş  \
# 0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1     2                 Elon Musk  $195 milyar   52
# 2     3                Jeff Bezos  $194 milyar   60
# 3     4           Mark Zuckerberg  $177 milyar   39
# 4     5             Larry Ellison  $141 milyar   79
# 5     6            Warren Buffett  $133 milyar   93
# 6     7                Bill Gates  $128 milyar   68
# 7     8             Steve Ballmer  $121 milyar   68
# 8     9             Mukesh Ambani  $116 milyar   67
# 9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# 4                        ABD   Oracle Corporation
# 5                        ABD   Berkshire Hathaway
# ...

# %% [markdown]
# # Web den CSV dosyası Okuma

# %%
df=pd.read_csv(r'https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2023-financial-year-provisional/Download-data/annual-enterprise-survey-2023-financial-year-provisional.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# # CSV olarak kaydetme

# %%
df.to_csv('Dunyanin_en_zenginleri.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3073-49B7
#
#  Directory of C:\Users\murat\Documents\BTKTemmuz2024\day4
#
# 19.07.2024  12:31    <DIR>          .
# 19.07.2024  11:40    <DIR>          ..
# 19.07.2024  12:26    <DIR>          .ipynb_checkpoints
# 19.07.2024  12:19    <DIR>          dataset
# 19.07.2024  12:08    <DIR>          deprem
# 19.07.2024  12:31               589 Dunyanin_en_zenginleri.csv
# 19.07.2024  12:30               610 Dunyanin_ne_zenginleri.csv
# 19.07.2024  12:26            41.634 Image-Downloader.ipynb
# 19.07.2024  12:11         1.430.381 once_sonra.html
# 19.07.2024  12:07    <DIR>          orman
# 19.07.2024  12:30             8.550 PAndas ile tablo okuma.ipynb
# 19.07.2024  12:14         1.635.848 slider once-sonra.ipynb
#                6 File(s)      3.117.612 bytes
#                6 Dir(s)  120.016.580.608 bytes free

# %%
data=pd.read_csv('Dunyanin_en_zenginleri.csv')
data
# Out:
#    Sıra                      İsim       Servet  Yaş  \
# 0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1     2                 Elon Musk  $195 milyar   52
# 2     3                Jeff Bezos  $194 milyar   60
# 3     4           Mark Zuckerberg  $177 milyar   39
# 4     5             Larry Ellison  $141 milyar   79
# 5     6            Warren Buffett  $133 milyar   93
# 6     7                Bill Gates  $128 milyar   68
# 7     8             Steve Ballmer  $121 milyar   68
# 8     9             Mukesh Ambani  $116 milyar   67
# 9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# 4                        ABD   Oracle Corporation
# 5                        ABD   Berkshire Hathaway
# ...

# %% [markdown]
# # Excel olarak kaydetme

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 435.7 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/250.9 kB 550.5 kB/s eta 0:00:01
#    --------------------- ---------------- 143.4/250.9 kB 950.9 kB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_excel('Dunyanin_en_zenginleri.xlsx',index=False)

# %%
data=pd.read_excel('Dunyanin_en_zenginleri.xlsx')
data
# Out:
#    Sıra                      İsim       Servet  Yaş  \
# 0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1     2                 Elon Musk  $195 milyar   52
# 2     3                Jeff Bezos  $194 milyar   60
# 3     4           Mark Zuckerberg  $177 milyar   39
# 4     5             Larry Ellison  $141 milyar   79
# 5     6            Warren Buffett  $133 milyar   93
# 6     7                Bill Gates  $128 milyar   68
# 7     8             Steve Ballmer  $121 milyar   68
# 8     9             Mukesh Ambani  $116 milyar   67
# 9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# 4                        ABD   Oracle Corporation
# 5                        ABD   Berkshire Hathaway
# ...

# %% [markdown]
# # Clipboard datayı okumak

# %%
df_clipboard=pd.read_clipboard()
df_clipboard
# Out:
#      ra                                               Ülke          Nüfus  \
# 0   1.0                                Hindistan Hindistan  1.425.775.850
# 1   2.0                                            Çin Çin  1.412.600.000
# 2   3.0  Amerika Birleşik Devletleri Amerika Birleşik D...    334.633.076
# 3   4.0                                Endonezya Endonezya    275.773.800
# 4   5.0                                  Pakistan Pakistan    229.488.994
# 5   6.0                                    Nijerya Nijerya    216.746.934
# 6   7.0                                  Brezilya Brezilya    216.024.545
# 7   8.0                                Bangladeş Bangladeş    168.220.000
# 8   9.0                                        Rusya Rusya    146.188.000
# 9  10.0                                    Meksika Meksika    128.271.248
#
#    Yüzde           Tarih Kaynak
# 0  %17,8   14 Nisan 2023   [36]
# 1  %17,6  31 Aralık 2021   [37]
# 2  %4,17   16 Nisan 2023   [38]
# ...

# %%
df_clipboard.to_csv('Dunya_nufusu.csv',index=False)
