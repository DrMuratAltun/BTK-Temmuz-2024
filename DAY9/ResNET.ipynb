# %% [markdown]
# # CNN ile Görüntü Tanıma

# %%
#pip install tensorflow

# %%
import tensorflow as tf
tf.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow as tf
#       2 tf.__version__
#
# ModuleNotFoundError: No module named 'tensorflow'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\murat\.conda\envs\jupyterlab\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\murat\.conda\envs\jupyterlab\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\murat\.conda\envs\jupyterlab\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\murat\.conda\envs\jupyterlab\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
# ...
